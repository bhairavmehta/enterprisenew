# %% [markdown]
# ## FC-VAE multi-modal anomaly detector

# %% [markdown]
# An unsupervised model for detecting anomaly whenever a deviation is found in comparison to normal behavior. FC-VAE does multimodal data fusion by combining sensor feature data over time. A learnable threshold is used to decide on anomalous behavior. In the case of MHHD the sensors are Apps, Key Strokes, URLs, (and potentially Voice, Camera, Registry Keys).

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import math
import json
from scipy.stats import norm
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix

import tensorflow as tf

import keras
from keras.layers import Input, Dense, Lambda, Layer
from keras.layers import LSTM, RepeatVector
from keras.models import Model
from keras import backend as K
from keras import metrics
from keras import optimizers
from keras.datasets import mnist

from keras.callbacks import ModelCheckpoint
from keras.callbacks import TensorBoard
from keras.callbacks import LearningRateScheduler 
from keras.callbacks import EarlyStopping

from keras.utils import plot_model
# Out:
# Using TensorFlow backend.

# %%
nab_path = './data/NAB'
nab_data_path = nab_path + '/data/'

labels_filename = '/labels/combined_labels.json'
train_file_name = 'artificialNoAnomaly/art_daily_no_noise.csv' 
test_file_name = 'artificialWithAnomaly/art_daily_jumpsup.csv'

#train_file_name = 'realAWSCloudwatch/rds_cpu_utilization_cc0c53.csv'
#test_file_name = 'realAWSCloudwatch/rds_cpu_utilization_e47b3b.csv'

labels_file = open(nab_path + labels_filename, 'r')
labels = json.loads(labels_file.read())
labels_file.close()

def load_data_frame_with_labels(file_name):
    data_frame = pd.read_csv(nab_data_path + file_name)
    data_frame['anomaly_label'] = data_frame['timestamp'].isin(
        labels[file_name]).astype(int)
    return data_frame

train_data_frame = load_data_frame_with_labels(train_file_name)
test_data_frame = load_data_frame_with_labels(test_file_name)

# %%
plt.plot(train_data_frame.loc[0:3000,'value'])

# %%
plt.plot(test_data_frame['value'])

# %%
train_data_frame_final = train_data_frame.loc[0:3000,:]
test_data_frame_final = test_data_frame

# %%
data_scaler = StandardScaler()
data_scaler.fit(train_data_frame_final[['value']].values)
train_data = data_scaler.transform(train_data_frame_final[['value']].values)
test_data = data_scaler.transform(test_data_frame_final[['value']].values)

# %%
DATA_PATH = './data/'

def step_decay(epoch):
    lr_init = 0.001
    drop = 0.5
    epochs_drop = 16
    lr_new = lr_init * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lr_new

class LR_hist(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.lr = []
    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.lr.append(step_decay(len(self.losses)))

# %%
def create_dataset(dataset, look_back=10):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        dataX.append(dataset[i:(i+look_back),:])
        dataY.append(dataset[i+look_back,:])

    return np.array(dataX), np.array(dataY)

# %%
X_data, y_data = create_dataset(train_data, look_back=64) #look_back = window_size
X_train, X_val, y_train, y_val = train_test_split(X_data, y_data, test_size=0.1, random_state=42)
X_test, y_test = create_dataset(test_data, look_back=64)  #look_back = window_size

# %%
X_train_flatten = np.reshape(X_train, (X_train.shape[0], np.prod(X_train.shape[1:])))
X_test_flatten = np.reshape(X_test, (X_test.shape[0], np.prod(X_test.shape[1:])))

# %%
#training params
batch_size = 128
num_epochs = 64 

#model params
original_dim = np.prod(X_train.shape[1:]) #64
#timesteps = X_train.shape[1]
#input_dim = X_train.shape[-1]
intermediate_dim = 16 #256
latent_dim = 2
epsilon_std = 1.0

# %%
#sampling layer
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = K.random_normal(shape=(K.shape(z_mean)[0], latent_dim), mean=0.0, stddev=epsilon_std)
    return z_mean + K.exp(z_log_sigma) * epsilon

# %%
#likelihood layer
def likelihood(args):
    x, x_decoded_mean, x_decoded_scale = args
    dist = tf.contrib.distributions.MultivariateNormalDiag(x_decoded_mean, x_decoded_scale)
    likelihood = dist.log_prob(x)  
    return likelihood

# %%
#VAE architecture

#encoder
x = Input(shape=(original_dim,), name='input_sequence')
h1 = Dense(intermediate_dim, activation='relu')(x)
h2 = Dense(intermediate_dim, activation='relu')(h1)
z_mean = Dense(latent_dim)(h2)
z_log_sigma = Dense(latent_dim, activation='softplus')(h2)

#sampling
z = Lambda(sampling, output_shape=(latent_dim,))([z_mean, z_log_sigma])

#decoder
decoder_h1 = Dense(intermediate_dim, activation='relu')
decoder_h2 = Dense(intermediate_dim, activation='relu')

decoder_loc = Dense(original_dim)
decoder_scale = Dense(original_dim, activation='softplus')

h_decoded1 = decoder_h1(z)
h_decoded2 = decoder_h2(h_decoded1)
x_decoded_mean = decoder_loc(h_decoded2)
x_decoded_scale = decoder_scale(h_decoded2)

like = Lambda(likelihood, output_shape=(original_dim,), name='likelihood')([x, x_decoded_mean, x_decoded_scale])
# Out:
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:4115: The name tf.random_normal is deprecated. Please use tf.random.normal instead.
#
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From <ipython-input-13-7e6d1e1307fb>:4: MultivariateNormalDiag.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_diag) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\contrib\distributions\python\ops\mvn_diag.py:224: MultivariateNormalLinearOperator.__init__ (from tensorflow.contrib.distributions.python.ops.mvn_linear_operator) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\contrib\distributions\python\ops\mvn_linear_operator.py:199: Normal.__init__ (from tensorflow.python.ops.distributions.normal) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\python\ops\distributions\normal.py:160: Distribution.__init__ (from tensorflow.python.ops.distributions.distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\contrib\distributions\python\ops\mvn_linear_operator.py:201: AffineLinearOperator.__init__ (from tensorflow.contrib.distributions.python.ops.bijectors.affine_linear_operator) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\contrib\distributions\python\ops\bijectors\affine_linear_operator.py:158: _DistributionShape.__init__ (from tensorflow.contrib.distributions.python.ops.shape) is deprecated and will be removed after 2018-10-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.contrib.distributions`.
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\contrib\distributions\python\ops\mvn_linear_operator.py:205: TransformedDistribution.__init__ (from tensorflow.python.ops.distributions.transformed_distribution) is deprecated and will be removed after 2019-01-01.
# Instructions for updating:
# The TensorFlow Distributions library has moved to TensorFlow Probability (https://github.com/tensorflow/probability). You should update all references to use `tfp.distributions` instead of `tf.distributions`.

# %%
#custom loss layer
class CustomVariationalLayer(Layer):
    def __init__(self, **kwargs):
        self.is_placeholder = True
        super(CustomVariationalLayer, self).__init__(**kwargs)
    
    def vae_loss(self, x, z_mean, z_log_sigma, likelihood):        
        kl_loss = - 0.5 * K.mean(1 + z_log_sigma - K.square(z_mean) - K.exp(z_log_sigma))
        loss = -K.mean(likelihood - kl_loss)
        return loss

    def call(self, inputs):
        x = inputs[0]
        z_mean = inputs[1]
        z_log_sigma = inputs[2]
        likelihood = inputs[3]
        loss = self.vae_loss(x, z_mean, z_log_sigma, likelihood)
        self.add_loss(loss, inputs=inputs)
        return x

# %%
y = CustomVariationalLayer()([x, z_mean, z_log_sigma, like])
vae_like = Model(x, like)
vae = Model(x, y)

# %%
adam = optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
vae.compile(loss=None, optimizer=adam, metrics=['accuracy'])
vae.summary()
# Out:
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_sequence (InputLayer)     (None, 64)           0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 16)           1040        input_sequence[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 16)           272         dense_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            34          dense_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            34          dense_2[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 2)            0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 16)           48          lambda_1[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 16)           272         dense_5[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 64)           1088        dense_6[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 64)           1088        dense_6[0][0]
# __________________________________________________________________________________________________
# likelihood (Lambda)             (None, 64)           0           input_sequence[0][0]
#                                                                  dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# custom_variational_layer_1 (Cus [(None, 64), (None,  0           input_sequence[0][0]
#                                                                  dense_3[0][0]
#                                                                  dense_4[0][0]
#                                                                  likelihood[0][0]
# ==================================================================================================
# Total params: 3,876
# Trainable params: 3,876
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#define callbacks
file_name = DATA_PATH + 'fc-vae-anomaly-detector.hdf5'
checkpoint = ModelCheckpoint(file_name, monitor='loss', verbose=1, save_best_only=True, mode='min')
tensor_board = TensorBoard(log_dir='./logs', write_graph=True)
hist_lr = LR_hist()
reduce_lr = LearningRateScheduler(step_decay) 
early_stopping = EarlyStopping(monitor='loss', min_delta=0.01, patience=64, verbose=1)
callbacks_list = [checkpoint, hist_lr, reduce_lr, early_stopping]

# %%
print("training vae model...")
hist = vae.fit(x=X_train_flatten, y=None, shuffle=True, epochs=num_epochs, batch_size=batch_size, callbacks=callbacks_list, validation_split=0.1, verbose=2)
# Out:
# training vae model...
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:2741: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 2377 samples, validate on 265 samples
# Epoch 1/64
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\keras\backend\tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 1s - loss: 136.8099 - val_loss: 112.9982
#
# Epoch 00001: loss improved from inf to 136.80987, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 2/64
#  - 0s - loss: 109.3064 - val_loss: 103.7775
#
# Epoch 00002: loss improved from 136.80987 to 109.30644, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 3/64
#  - 0s - loss: 103.5200 - val_loss: 100.2534
#
# Epoch 00003: loss improved from 109.30644 to 103.51997, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 4/64
#  - 0s - loss: 99.7234 - val_loss: 97.9403
#
# Epoch 00004: loss improved from 103.51997 to 99.72337, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 5/64
#  - 0s - loss: 96.1298 - val_loss: 93.1613
#
# Epoch 00005: loss improved from 99.72337 to 96.12978, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 6/64
#  - 0s - loss: 91.3213 - val_loss: 88.4412
#
# Epoch 00006: loss improved from 96.12978 to 91.32129, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 7/64
#  - 0s - loss: 86.2334 - val_loss: 83.1529
#
# Epoch 00007: loss improved from 91.32129 to 86.23338, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 8/64
#  - 0s - loss: 81.0106 - val_loss: 77.1637
#
# Epoch 00008: loss improved from 86.23338 to 81.01063, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 9/64
#  - 0s - loss: 74.7052 - val_loss: 71.0670
#
# Epoch 00009: loss improved from 81.01063 to 74.70519, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 10/64
#  - 0s - loss: 67.9035 - val_loss: 63.4302
#
# Epoch 00010: loss improved from 74.70519 to 67.90349, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 11/64
#  - 0s - loss: 60.0014 - val_loss: 55.2950
#
# Epoch 00011: loss improved from 67.90349 to 60.00138, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 12/64
#  - 0s - loss: 51.6552 - val_loss: 44.9091
#
# Epoch 00012: loss improved from 60.00138 to 51.65521, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 13/64
#  - 0s - loss: 41.8312 - val_loss: 37.3395
#
# Epoch 00013: loss improved from 51.65521 to 41.83124, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 14/64
#  - 0s - loss: 34.0940 - val_loss: 28.2651
#
# Epoch 00014: loss improved from 41.83124 to 34.09401, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 15/64
#  - 0s - loss: 28.4496 - val_loss: 24.8941
#
# Epoch 00015: loss improved from 34.09401 to 28.44960, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 16/64
#  - 0s - loss: 24.9962 - val_loss: 25.6653
#
# Epoch 00016: loss improved from 28.44960 to 24.99621, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 17/64
#  - 0s - loss: 23.5682 - val_loss: 21.5400
#
# Epoch 00017: loss improved from 24.99621 to 23.56821, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 18/64
#  - 0s - loss: 22.9907 - val_loss: 19.1380
#
# Epoch 00018: loss improved from 23.56821 to 22.99072, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 19/64
#  - 0s - loss: 21.0893 - val_loss: 22.3945
#
# Epoch 00019: loss improved from 22.99072 to 21.08926, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 20/64
#  - 0s - loss: 20.5607 - val_loss: 19.4493
#
# Epoch 00020: loss improved from 21.08926 to 20.56069, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 21/64
#  - 0s - loss: 19.4437 - val_loss: 17.8838
#
# Epoch 00021: loss improved from 20.56069 to 19.44366, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 22/64
#  - 0s - loss: 17.6804 - val_loss: 19.8106
#
# Epoch 00022: loss improved from 19.44366 to 17.68043, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 23/64
#  - 0s - loss: 16.4570 - val_loss: 24.4073
#
# Epoch 00023: loss improved from 17.68043 to 16.45704, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 24/64
#  - 0s - loss: 15.8561 - val_loss: 16.2806
#
# Epoch 00024: loss improved from 16.45704 to 15.85605, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 25/64
#  - 0s - loss: 14.3303 - val_loss: 12.0235
#
# Epoch 00025: loss improved from 15.85605 to 14.33034, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 26/64
#  - 0s - loss: 12.5741 - val_loss: 11.5598
#
# Epoch 00026: loss improved from 14.33034 to 12.57415, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 27/64
#  - 0s - loss: 13.8100 - val_loss: 16.2521
#
# Epoch 00027: loss did not improve from 12.57415
# Epoch 28/64
#  - 0s - loss: 13.6022 - val_loss: 11.8239
#
# Epoch 00028: loss did not improve from 12.57415
# Epoch 29/64
#  - 0s - loss: 12.6517 - val_loss: 10.5355
#
# Epoch 00029: loss did not improve from 12.57415
# Epoch 30/64
#  - 0s - loss: 11.8758 - val_loss: 10.1326
#
# Epoch 00030: loss improved from 12.57415 to 11.87584, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 31/64
#  - 0s - loss: 9.5686 - val_loss: 11.3810
#
# Epoch 00031: loss improved from 11.87584 to 9.56865, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 32/64
#  - 0s - loss: 8.3842 - val_loss: 9.0727
#
# Epoch 00032: loss improved from 9.56865 to 8.38421, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 33/64
#  - 0s - loss: 8.8639 - val_loss: 2.5457
#
# Epoch 00033: loss did not improve from 8.38421
# Epoch 34/64
#  - 0s - loss: 8.1581 - val_loss: 6.7603
#
# Epoch 00034: loss improved from 8.38421 to 8.15814, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 35/64
#  - 0s - loss: 7.1945 - val_loss: 9.0168
#
# Epoch 00035: loss improved from 8.15814 to 7.19450, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 36/64
#  - 0s - loss: 6.2963 - val_loss: 8.6208
#
# Epoch 00036: loss improved from 7.19450 to 6.29633, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 37/64
#  - 0s - loss: 5.3179 - val_loss: 3.5876
#
# Epoch 00037: loss improved from 6.29633 to 5.31791, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 38/64
#  - 0s - loss: 5.4293 - val_loss: -7.7904e-01
#
# Epoch 00038: loss did not improve from 5.31791
# Epoch 39/64
#  - 0s - loss: 3.2428 - val_loss: 1.7594
#
# Epoch 00039: loss improved from 5.31791 to 3.24283, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 40/64
#  - 0s - loss: 5.3752 - val_loss: 3.5292
#
# Epoch 00040: loss did not improve from 3.24283
# Epoch 41/64
#  - 0s - loss: 3.8852 - val_loss: 11.7729
#
# Epoch 00041: loss did not improve from 3.24283
# Epoch 42/64
#  - 0s - loss: 4.3259 - val_loss: 3.0679
#
# Epoch 00042: loss did not improve from 3.24283
# Epoch 43/64
#  - 0s - loss: 2.9591 - val_loss: 17.0681
#
# Epoch 00043: loss improved from 3.24283 to 2.95911, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 44/64
#  - 0s - loss: 0.7586 - val_loss: -1.1388e+00
#
# Epoch 00044: loss improved from 2.95911 to 0.75856, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 45/64
#  - 0s - loss: 0.6883 - val_loss: 1.1106
#
# Epoch 00045: loss improved from 0.75856 to 0.68830, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 46/64
#  - 0s - loss: 1.4670 - val_loss: -5.4137e-01
#
# Epoch 00046: loss did not improve from 0.68830
# Epoch 47/64
#  - 0s - loss: 0.4371 - val_loss: -2.0461e+00
#
# Epoch 00047: loss improved from 0.68830 to 0.43710, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 48/64
#  - 0s - loss: -2.1638e-01 - val_loss: -1.0314e+00
#
# Epoch 00048: loss improved from 0.43710 to -0.21638, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 49/64
#  - 0s - loss: -2.5714e+00 - val_loss: 0.7794
#
# Epoch 00049: loss improved from -0.21638 to -2.57140, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 50/64
#  - 0s - loss: -2.1396e+00 - val_loss: -2.7500e+00
#
# Epoch 00050: loss did not improve from -2.57140
# Epoch 51/64
#  - 0s - loss: -2.5780e+00 - val_loss: -5.1393e+00
#
# Epoch 00051: loss improved from -2.57140 to -2.57801, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 52/64
#  - 0s - loss: -1.6641e+00 - val_loss: -6.1704e+00
#
# Epoch 00052: loss did not improve from -2.57801
# Epoch 53/64
#  - 0s - loss: -3.1453e+00 - val_loss: -3.4795e+00
#
# Epoch 00053: loss improved from -2.57801 to -3.14526, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 54/64
#  - 0s - loss: -3.3982e+00 - val_loss: -1.6742e+00
#
# Epoch 00054: loss improved from -3.14526 to -3.39817, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 55/64
#  - 0s - loss: -4.4353e+00 - val_loss: -7.6802e+00
#
# Epoch 00055: loss improved from -3.39817 to -4.43532, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 56/64
#  - 0s - loss: -3.3828e+00 - val_loss: -6.7883e+00
#
# Epoch 00056: loss did not improve from -4.43532
# Epoch 57/64
#  - 0s - loss: -3.3219e+00 - val_loss: -1.1111e+01
#
# Epoch 00057: loss did not improve from -4.43532
# Epoch 58/64
#  - 0s - loss: -2.3450e+00 - val_loss: -7.7050e+00
#
# Epoch 00058: loss did not improve from -4.43532
# Epoch 59/64
#  - 0s - loss: -4.9212e+00 - val_loss: -5.3561e+00
#
# Epoch 00059: loss improved from -4.43532 to -4.92117, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 60/64
#  - 0s - loss: -3.4318e+00 - val_loss: -4.7008e+00
#
# Epoch 00060: loss did not improve from -4.92117
# Epoch 61/64
#  - 0s - loss: -6.3547e+00 - val_loss: -5.7735e+00
#
# Epoch 00061: loss improved from -4.92117 to -6.35472, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 62/64
#  - 0s - loss: -6.1339e+00 - val_loss: -7.9065e+00
#
# Epoch 00062: loss did not improve from -6.35472
# Epoch 63/64
#  - 0s - loss: -6.4447e+00 - val_loss: -6.5309e+00
#
# Epoch 00063: loss improved from -6.35472 to -6.44466, saving model to ./data/fc-vae-anomaly-detector.hdf5
# Epoch 64/64
#  - 0s - loss: -7.6283e+00 - val_loss: -8.7751e+00
#
# Epoch 00064: loss improved from -6.44466 to -7.62830, saving model to ./data/fc-vae-anomaly-detector.hdf5

# %%
#vae.save(DATA_PATH + 'fc-vae-final_model.h5', overwrite=True)
#vae.save_weights(DATA_PATH + 'fc-vae-final_weights.h5', overwrite=True)

# %%
#load saved model
#vae = load_model(DATA_PATH + 'final_model.h5')

# %%
#generate plots

plt.figure()
plt.plot(hist.history['loss'], lw=2.0, c='b', label='training loss')
plt.plot(hist.history['val_loss'], lw=2.0, c='r', label='validation loss')
plt.title('VAE model')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.legend()
plt.savefig('./figures/lstm_vae_training_loss.png')


plt.figure()
plt.plot(hist_lr.lr, lw=2.0, label='learning rate')
plt.title('VAE model')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.savefig('./figures/lstm_vae_learning_rate.png')

# %%
pred_test_flatten = vae_like.predict(X_test_flatten)
plt.plot(pred_test_flatten)

# %%
nan_idx = np.isnan(pred_test_flatten)
pred_test_flatten[nan_idx] = 0
plt.plot(pred_test_flatten)

# %%
is_anomaly = pred_test_flatten < -1e4
plt.figure()
plt.plot(test_data, color='b')
plt.figure()
plt.plot(is_anomaly, color='r')

# %% [markdown]
# ## Keras to TensorFlow .pb file

# %%
#https://stackoverflow.com/questions/45466020/how-to-export-keras-h5-to-tensorflow-pb
def freeze_session(session, keep_var_names=None, output_names=None, clear_devices=True):
    """
    Freezes the state of a session into a pruned computation graph.

    Creates a new computation graph where variable nodes are replaced by
    constants taking their current value in the session. The new graph will be
    pruned so subgraphs that are not necessary to compute the requested
    outputs are removed.
    @param session The TensorFlow session to be frozen.
    @param keep_var_names A list of variable names that should not be frozen,
                          or None to freeze all the variables in the graph.
    @param output_names Names of the relevant graph outputs.
    @param clear_devices Remove the device directives from the graph for better portability.
    @return The frozen graph definition.
    """
    graph = session.graph
    with graph.as_default():
        freeze_var_names = list(set(v.op.name for v in tf.global_variables()).difference(keep_var_names or []))
        output_names = output_names or []
        output_names += [v.op.name for v in tf.global_variables()]
        input_graph_def = graph.as_graph_def()
        if clear_devices:
            for node in input_graph_def.node:
                node.device = ""
        frozen_graph = tf.graph_util.convert_variables_to_constants(
            session, input_graph_def, output_names, freeze_var_names)
        return frozen_graph

# %%
from keras import backend as K
frozen_graph = freeze_session(K.get_session(),
                              output_names=[out.op.name for out in vae_like.outputs])
# Out:
# WARNING:tensorflow:From <ipython-input-25-fbcc4a820ba6>:27: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# WARNING:tensorflow:From c:\tools\anaconda3\envs\vss\lib\site-packages\tensorflow_core\python\framework\graph_util_impl.py:277: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# INFO:tensorflow:Froze 69 variables.
# INFO:tensorflow:Converted 69 variables to const ops.

# %%
tf.train.write_graph(frozen_graph, "./data", "fc-vae-anomaly-detector.pb", as_text=False)
# Out:
# './data\\fc-vae-anomaly-detector.pb'

# %% [markdown]
# ## Load the model and use it in TensorFlow

# %%
tf.reset_default_graph()
output_tf_model = 'fc-vae-anomaly-detector.pb'
graph = tf.Graph()
with tf.gfile.GFile('./data/' + output_tf_model, 'rb') as f:
    graph_def = tf.GraphDef()
    graph_def.ParseFromString(f.read())

# %%
with graph.as_default():
    # Define input tensor
    input_tensor = tf.placeholder(np.float32, shape = [None, original_dim])
    tf.import_graph_def(graph_def, {'input_sequence': input_tensor})
graph.finalize()

# %%
vae_like.layers[-1].output
# Out:
# <tf.Tensor 'likelihood/MultivariateNormalDiag/log_prob/add:0' shape=(?,) dtype=float32>

# %%
sess = tf.Session(graph=graph)
output_tensor = graph.get_tensor_by_name("import/likelihood/MultivariateNormalDiag/log_prob/add:0")
pred_loaded_model = sess.run(output_tensor, feed_dict={input_tensor: X_test_flatten})

# %%
plt.plot(pred_loaded_model)

# %% [markdown]
# ## References

# %% [markdown]
# [1] Park et al., "A Multimodal Anomaly Detector for Robot-Assisted Feeding Using an LSTM-Based Variational Autoencoder", arXiv 2018: https://arxiv.org/pdf/1711.00614.pdf
# [2] Zhang et al, "Time Series Anomaly Detection with Variational Autoencoders": https://arxiv.org/pdf/1907.01702.pdf
# [3] An et al, "Variational Autoencoder based Anomaly Detection using Reconstruction Probability": http://dm.snu.ac.kr/static/docs/TR/SNUDM-TR-2015-03.pdf  |
